# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
detail_results_df = pd.merge(mouse_metadata, study_results,
                                 how='outer', on='Mouse ID')

# Display the data table to see how many rows total
# detail_results_df

# %%
# Checking the number of mice.
detail_results_df["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Optional: Get all the data for the duplicate mouse ID. 
detail_results_df.loc[detail_results_df.duplicated(['Mouse ID','Timepoint']), :]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
#Set index to mouse ID
detail_results_df = detail_results_df.set_index("Mouse ID")
detail_results_df.head()
# Out:
#          Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# k403         Ramicane  Male          21          16          0
# k403         Ramicane  Male          21          16          5
# k403         Ramicane  Male          21          16         10
# k403         Ramicane  Male          21          16         15
# k403         Ramicane  Male          21          16         20
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# k403               45.000000                 0
# k403               38.825898                 0
# k403               35.014271                 1
# k403               34.223992                 1
# k403               32.997729                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# Drop duplicated mouse by removing the index which was set to it's ID above
cleaned_df=detail_results_df.drop(["g989"])
#cleaned_df

# %%
# Reset index
cleaned_df=cleaned_df.reset_index()
#cleaned_df

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_df["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume
clean_mean = np.mean(cleaned_df["Tumor Volume (mm3)"])
print(f"Mean Tumor Volume is: {clean_mean}")
clean_median = np.median(cleaned_df["Tumor Volume (mm3)"])
print(f"Median Tumor Volume is: {clean_median}")
clean_variance = np.var(cleaned_df["Tumor Volume (mm3)"], ddof=8)
print(f"The variance of the Tumor Volume is: {clean_variance}")
clean_sd = np.std(cleaned_df["Tumor Volume (mm3)"], ddof=0)
print(f"The Standard Deviation of the Tumor Volume is: {clean_sd}")

# Standard Error of Measurement
print(f"Roughly 68% of the tumors are between {round(clean_mean-clean_sd,3)} (mm3) and {round(clean_mean+clean_sd,3)} (mm3).")
print(f"Roughly 95% of the tumors are between {round(clean_mean-2*clean_sd,3)} (mm3) and {round(clean_mean+2*clean_sd,3)} (mm3).")
print(f"Roughly 99.7% of the tumors are between {round(clean_mean-3*clean_sd,3)} (mm3) and {round(clean_mean+3*clean_sd,3)} (mm3).")
# Out:
# Mean Tumor Volume is: 50.435293232255326
# Median Tumor Volume is: 48.933453655
# The variance of the Tumor Volume is: 79.7600440846857
# The Standard Deviation of the Tumor Volume is: 8.911825830982792
# Roughly 68% of the tumors are between 41.523 (mm3) and 59.347 (mm3).
# Roughly 95% of the tumors are between 32.612 (mm3) and 68.259 (mm3).
# Roughly 99.7% of the tumors are between 23.7 (mm3) and 77.171 (mm3).

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

# Use groupby
by_regimen_df=cleaned_df.groupby(["Drug Regimen"])
by_regimen_df.count()

#confirm groupby and see summary stats of Tumor Volume (Use this to check answes as applicable)
by_regimen_df["Tumor Volume (mm3)"].describe()
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin     230.0  40.675741  4.994774  23.343598  37.685933  41.557809
# Ceftamin      178.0  52.591172  6.268188  45.000000  47.208427  51.776157
# Infubinol     178.0  52.884795  6.567243  36.321346  47.312353  51.820584
# Ketapril      188.0  55.235638  8.279709  45.000000  48.232987  53.698743
# Naftisol      186.0  54.331565  8.134708  45.000000  47.285874  52.509285
# Placebo       181.0  54.033581  7.821003  45.000000  47.459053  52.288934
# Propriva      148.0  52.320930  6.622085  45.000000  46.894328  50.446266
# Ramicane      228.0  40.216745  4.846308  22.050126  36.674635  40.673236
# Stelasyn      181.0  54.233149  7.710419  45.000000  48.047139  52.431737
# Zoniferol     182.0  53.236507  6.966589  45.000000  47.337876  51.818479
#
#                     75%        max
# Drug Regimen
# Capomulin     45.000000  48.158209
# Ceftamin      56.801438  68.923185
# Infubinol     57.314444  72.226731
# Ketapril      60.870951  78.567014
# Naftisol      59.963034  76.668817
# Placebo       59.916934  73.212939
# Propriva      56.491585  72.455421
# Ramicane      45.000000  47.622816
# Stelasyn      58.719297  75.123690
# Zoniferol     57.954259  73.324432

# %%
#Calculate the required properties
grouped_mean = by_regimen_df["Tumor Volume (mm3)"].mean()
grouped_median = by_regimen_df["Tumor Volume (mm3)"].median()
grouped_variance = by_regimen_df["Tumor Volume (mm3)"].var()
grouped_sd= by_regimen_df["Tumor Volume (mm3)"].std()
lower68=(grouped_mean-grouped_sd)
upper68=(grouped_mean+grouped_sd)
lower95=(grouped_mean-(2*grouped_sd))
upper95=(grouped_mean+(2*grouped_sd))
lower99=(grouped_mean-(3*grouped_sd))
upper99=(grouped_mean+(3*grouped_sd))

grouped_sem1= by_regimen_df["Tumor Volume (mm3)"].sem(ddof=1)
grouped_sem2= by_regimen_df["Tumor Volume (mm3)"].sem(ddof=2)
grouped_sem3= by_regimen_df["Tumor Volume (mm3)"].sem(ddof=3)

# Assemble the resulting series into a single summary dataframe.
drug_regimen_summary=pd.DataFrame({ "Mean": grouped_mean, "Median": grouped_median, "Variance": grouped_variance,
                                  "Standard Deviation": grouped_sd, "68% Lower": lower68,  "68% Upper": upper68,
                                 "95% Lower": lower95, "95% Upper":upper95, "99.7% Lower": lower99,  "99.7% Upper": upper99})
drug_regimen_summary
# Out:
#                    Mean     Median   Variance  Standard Deviation  68% Lower  \
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  35.680967
# Ceftamin      52.591172  51.776157  39.290177            6.268188  46.322984
# Infubinol     52.884795  51.820584  43.128684            6.567243  46.317552
# Ketapril      55.235638  53.698743  68.553577            8.279709  46.955929
# Naftisol      54.331565  52.509285  66.173479            8.134708  46.196856
# Placebo       54.033581  52.288934  61.168083            7.821003  46.212578
# Propriva      52.320930  50.446266  43.852013            6.622085  45.698845
# Ramicane      40.216745  40.673236  23.486704            4.846308  35.370437
# Stelasyn      54.233149  52.431737  59.450562            7.710419  46.522730
# Zoniferol     53.236507  51.818479  48.533355            6.966589  46.269918
#
#               68% Upper  95% Lower  95% Upper  99.7% Lower  99.7% Upper
# Drug Regimen
# Capomulin     45.670515  30.686194  50.665289    25.691420    55.660062
# Ceftamin      58.859360  40.054796  65.127547    33.786609    71.395735
# Infubinol     59.452038  39.750309  66.019282    33.183065    72.586525
# Ketapril      63.515346  38.676220  71.795055    30.396511    80.074764
# Naftisol      62.466273  38.062148  70.600981    29.927440    78.735690
# Placebo       61.854583  38.391575  69.675586    30.570573    77.496589
# Propriva      58.943015  39.076759  65.565100    32.454674    72.187186
# Ramicane      45.063053  30.524129  49.909362    25.677820    54.755670
# Stelasyn      61.943568  38.812311  69.653987    31.101892    77.364406
# Zoniferol     60.203095  39.303330  67.169684    32.336741    74.136272

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

agg_results=cleaned_df.groupby(["Drug Regimen"]).agg({"Tumor Volume (mm3)": [np.mean, np.median,np.var, np.std, st.sem]})

agg_results
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

#Create new DF using only the two series needed
time_reg_df=cleaned_df[["Drug Regimen", "Timepoint"]]
#groupby the regimen
time_reg_df=time_reg_df.groupby("Drug Regimen").count()

time_reg_df.head()
# Out:
#               Timepoint
# Drug Regimen
# Capomulin           230
# Ceftamin            178
# Infubinol           178
# Ketapril            188
# Naftisol            186

# %%
# Configure plot and ticks, assign title and format
time_reg_df.plot(kind="bar", figsize=(7,5))
plt.title("Timepoints per Drug Regimen")

plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
#reset index so can use "Drug Regimen" as a lable
time_reg_df=time_reg_df.reset_index()

# Set x axis and tick locations

x_axis = np.arange(len(time_reg_df))
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(7,5))
plt.bar(x_axis, time_reg_df["Timepoint"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, time_reg_df["Drug Regimen"], rotation="vertical")

# Set a Title and labels
plt.title("Timepoints per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Timepoints")



plt.show()

# %%
# Get counts of Mice by gender to make the Pie Plots

#Get one mouse per ID
one_per=cleaned_df.drop_duplicates(subset=["Mouse ID"])
#group by "Sex"
grouped_gender_df=one_per.groupby(["Sex"])
#count those groups
gender_count=grouped_gender_df.count()
gender_count
# Out:
#         index  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# Sex
# Female    123       123           123         123         123        123
# Male      125       125           125         125         125        125
#
#         Tumor Volume (mm3)  Metastatic Sites
# Sex
# Female                 123               123
# Male                   125               125

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

#generate pie plot
#you can use any key as Y since the counts are by gender
#to not make it confusing drop the Y label
gender_count.plot(kind='pie', y='Mouse ID',ylabel=' ',autopct="%1.1f%%", title="Mice by Gender")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

#setting parameters
y= grouped_gender_df["Sex"].count()
mylabels=["Male", "Female"]
colors=["blue", "pink"]

#draw the plot using parameters set above
#purposely used different colors and different alignment
plt.pie(y, labels=mylabels, colors=colors, autopct="%1.1f%%", startangle=90)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin,Ramicane , Infubinol, and Ceftamin

drug_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

filtered_df = cleaned_df[cleaned_df['Drug Regimen'].isin(drug_list)]

filtered_df
# Out:
#       index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0         0     k403     Ramicane    Male          21          16          0
# 1         1     k403     Ramicane    Male          21          16          5
# 2         2     k403     Ramicane    Male          21          16         10
# 3         3     k403     Ramicane    Male          21          16         15
# 4         4     k403     Ramicane    Male          21          16         20
# ...     ...      ...          ...     ...         ...         ...        ...
# 1855   1855     z581    Infubinol  Female          24          25         25
# 1856   1856     z581    Infubinol  Female          24          25         30
# 1857   1857     z581    Infubinol  Female          24          25         35
# 1858   1858     z581    Infubinol  Female          24          25         40
# 1859   1859     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1855           54.316407                 2
# 1856           56.286750                 2
# 1857           58.628399                 3
# 1858           60.053740                 3
# 1859           62.754451                 3
#
# [814 rows x 9 columns]

# %%
# Start by getting the last (greatest) timepoint for each mouse
filtered_df["last_tp"]=filtered_df.drop_duplicates(subset=["Mouse ID"], keep='last')

filtered_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_tp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in _set_item_mgr(self, key, value)
#    3750         try:
# -> 3751             loc = self._info_axis.get_loc(key)
#    3752         except KeyError:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 'last_tp'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/qc/_ykx45d102d0nr51ysx4tb4h0000gn/T/ipykernel_44692/1504270788.py in <module>
#       1 # Start by getting the last (greatest) timepoint for each mouse
# ----> 2 filtered_df["last_tp"]=filtered_df.drop_duplicates(subset=["Mouse ID"], keep='last')
#       3
#       4 filtered_df
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3740         # now align rows
#    3741         arraylike = _reindex_for_setitem(value, self.index)
# -> 3742         self._set_item_mgr(key, arraylike)
#    3743
#    3744     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in _set_item_mgr(self, key, value)
#    3752         except KeyError:
#    3753             # This item wasn't present, just insert at end
# -> 3754             self._mgr.insert(len(self._info_axis), key, value)
#    3755         else:
#    3756             self._iset_item_mgr(loc, value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value)
#    1160             value = ensure_block_shape(value, ndim=self.ndim)
#    1161
# -> 1162         block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1163
#    1164         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/internals/blocks.py in new_block(values, placement, ndim, klass)
#    1935
#    1936     values, _ = extract_pandas_array(values, None, ndim)
# -> 1937     check_ndim(values, placement, ndim)
#    1938
#    1939     if klass is None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/internals/blocks.py in check_ndim(values, placement, ndim)
#    1978         if len(placement) != len(values):
#    1979             raise ValueError(
# -> 1980                 f"Wrong number of items passed {len(values)}, "
#    1981                 f"placement implies {len(placement)}"
#    1982             )
#
# ValueError: Wrong number of items passed 9, placement implies 1

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_list

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol=[]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
capomulin_df=cleaned_df.loc[cleaned_df['Drug Regimen'] == "Capomulin",:]
capomulin_df
# Out:
#       index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       10     s185    Capomulin  Female           3          17          0
# 11       11     s185    Capomulin  Female           3          17          5
# 12       12     s185    Capomulin  Female           3          17         10
# 13       13     s185    Capomulin  Female           3          17         15
# 14       14     s185    Capomulin  Female           3          17         20
# ...     ...      ...          ...     ...         ...         ...        ...
# 440     440     i557    Capomulin  Female           1          24         45
# 1439   1439     r157    Capomulin    Male          22          25          0
# 1440   1440     r157    Capomulin    Male          22          25          5
# 1441   1441     r157    Capomulin    Male          22          25         10
# 1442   1442     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# 11             43.878496                 0
# 12             37.614948                 0
# 13             38.177232                 0
# 14             36.866876                 0
# ...                  ...               ...
# 440            47.685963                 1
# 1439           45.000000                 0
# 1440           45.597064                 0
# 1441           46.059608                 0
# 1442           46.539206                 0
#
# [230 rows x 9 columns]

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
#Choose a sample mouse, in this case I picked i557
sample=capomulin_df.loc[capomulin_df["Mouse ID"] =="i557",:]
sample
# Out:
#      index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 431    431     i557    Capomulin  Female           1          24          0
# 432    432     i557    Capomulin  Female           1          24          5
# 433    433     i557    Capomulin  Female           1          24         10
# 434    434     i557    Capomulin  Female           1          24         15
# 435    435     i557    Capomulin  Female           1          24         20
# 436    436     i557    Capomulin  Female           1          24         25
# 437    437     i557    Capomulin  Female           1          24         30
# 438    438     i557    Capomulin  Female           1          24         35
# 439    439     i557    Capomulin  Female           1          24         40
# 440    440     i557    Capomulin  Female           1          24         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 431           45.000000                 0
# 432           42.261665                 0
# 433           42.992077                 0
# 434           43.529876                 0
# 435           43.967895                 0
# 436           44.596219                 0
# 437           45.261384                 0
# 438           45.941949                 0
# 439           46.821070                 1
# 440           47.685963                 1

# %%
#define data for plot- to_numpy() puts the values into an array without the index
time=sample['Timepoint'].to_numpy()
size=sample["Tumor Volume (mm3)"].to_numpy()
#size
#time

# %%
#Generate Plot
plt.plot(time, size,linewidth=1, marker="o", color="blue")

#adjust labels
plt.title("Mouse i557 treated with Capomulin")
plt.xlabel("TimePoints")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Group the camomulin mice by ID number in order to find mean.
avg_volume=capomulin_df.groupby("Mouse ID")
# avg_volume.count()

# %%
#set variable names as means of grouped and filtered Mice 
weight = avg_volume['Weight (g)'].mean()
tumor_vol = avg_volume['Tumor Volume (mm3)'].mean()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
plt.scatter(weight, tumor_vol, marker="o", facecolors="red", edgecolors="black")
#set limits w/in one of min max for each measurement
plt.ylim(33, 47)
plt.xlim(16,26)
#set title and labels
plt.title("Tumor Volume Average v Weight for Mice on Capomulin Regimen")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume Average (mm3)")


plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
